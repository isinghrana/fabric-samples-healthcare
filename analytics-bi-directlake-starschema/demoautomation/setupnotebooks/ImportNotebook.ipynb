# %%
# %pip install semantic-link==0.11.0 semantic-link-labs==0.10.1

# %%
download_cmsdata_notebook_url = "https://raw.githubusercontent.com/isinghrana/fabric-samples-healthcare/refs/heads/isr-auto1/analytics-bi-directlake-starschema/demoautomation/01-DownloadCMSDataCsvFiles.ipynb"
download_cmsdata_notebook_name = "01-DownloadCMSDataCsvFiles2"

create_data_table_notebook_url = "https://raw.githubusercontent.com/isinghrana/fabric-samples-healthcare/refs/heads/isr-auto1/analytics-bi-directlake-starschema/demoautomation/02-CreateCMSDataTable.ipynb"
create_data_table_notebook_name = "02-CreateCMSDataTable"

create_starschema_table_notebook_url = "https://raw.githubusercontent.com/isinghrana/fabric-samples-healthcare/refs/heads/isr-auto1/analytics-bi-directlake-starschema/demoautomation/03-CreateCMSStarSchemaTables.ipynb"
create_starschema_table_notebook_name = "03-CreateCMSStarSchemaTables"

# %%
import sempy_labs as labs
result = labs.import_notebook_from_web(notebook_name = download_cmsdata_notebook_name, url = download_cmsdata_notebook_url)
print(f"Download {download_cmsdata_notebook_name} result: {result}")
result = labs.import_notebook_from_web(notebook_name = create_data_table_notebook_name, url = create_data_table_notebook_url)
print(f"Download {create_data_table_notebook_name} result: {result}")
result = labs.import_notebook_from_web(notebook_name = create_starschema_table_notebook_name, url = create_starschema_table_notebook_url)
print(f"Download {create_starschema_table_notebook_name} result: {result}")

# %%
import sempy.fabric as fabric
download_cmsdata_notebook_id = fabric.resolve_item_id(item_name = download_cmsdata_notebook_name, type = "Notebook")
print(f"download_cmsdata_notebook_id: {download_cmsdata_notebook_id}")

create_data_table_notebook_id = fabric.resolve_item_id(item_name = create_data_table_notebook_name, type = "Notebook")
print(f"create_data_table_notebook_id: {create_data_table_notebook_id}")

create_starschema_table_notebook_id = fabric.resolve_item_id(item_name = create_starschema_table_notebook_name, type = "Notebook")
print(f"create_starschema_notebook_id: {create_starschema_table_notebook_id}")
